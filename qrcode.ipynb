# %% [markdown]
# <a href="https://colab.research.google.com/github/Alamzaibsahito/Assignment-04/blob/main/qrcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qrcode[pil]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 2.0 MB/s eta 0:00:00
# ...

# %%
import qrcode
import cv2
import numpy as np
from PIL import Image
from IPython.display import display

# ✅ QR Code Generator Function
def generate_qr_code(data, filename="qrcode.png"):
    qr = qrcode.QRCode(
        version=1,
        box_size=10,
        border=5
    )
    qr.add_data(data)
    qr.make(fit=True)

    # ✅ Correct parameters
    img = qr.make_image(fill_color="blue", back_color="white")
    img.save(filename)
    display(img)
    print(f"✅ QR Code saved as {filename}")

# ✅ QR Code Decoder Function
def decode_qr(filename):
    img = cv2.imread(filename)
    detector = cv2.QRCodeDetector()
    data, bbox, _ = detector.detectAndDecode(img)

    if data:
        print(f"QR Code Decoded: {data}")
    else:
        print("❌ No QR Code found in the image.")

# ✅ Run the Functions
generate_qr_code("✅Successfully Generated", "my_qr.png")
decode_qr("my_qr.png")
# Out:
# ✅ QR Code saved as my_qr.png
# QR Code Decoded: ✅Successfully Generated
